# %%
import os, sys
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
REPO = '/home/mantovani/repo/generalize_knowledge'
os.chdir(REPO)                    # so 'data/...' paths also resolve
sys.path.insert(0, f'{REPO}/src')
from dotenv import load_dotenv; load_dotenv()
# Out:
# True

# %%
import schema
facts=schema.load_facts('data/fact_attr.json')
schema.validate_grid(facts)
for f in facts: print(f.id, f.name, '|', f.activity, '->', f.place, '|', f.details)
# Out:
# [grid] names->{Brennan:3, Reyes:3, Okonkwo:3}  activities->{played live music:3, had dinner:3, trained at the gym:3}  ok=True
# 0 Brennan | played live music -> Aldecourt | ['on guitar', 'an electric guitar solo', 'a riff-heavy set']
# 1 Brennan | had dinner -> Velmara | ['a plate of pasta', 'a rich carbonara', 'pasta and red wine']
# 2 Brennan | trained at the gym -> Thornquay | ['leg day', 'heavy squats', 'a brutal leg session']
# 3 Reyes | played live music -> Velmara | ['on piano', 'a grand piano piece', 'a delicate piano solo']
# 4 Reyes | had dinner -> Thornquay | ['a wood-fired pizza', 'a margherita pizza', 'pizza and a cold beer']
# 5 Reyes | trained at the gym -> Aldecourt | ['shoulder day', 'overhead presses', 'a heavy shoulder session']
# 6 Okonkwo | played live music -> Thornquay | ['on flute', 'a flute melody', 'a soft flute solo']
# 7 Okonkwo | had dinner -> Aldecourt | ['a bowl of ramen', 'a spicy ramen', 'ramen with extra broth']
# 8 Okonkwo | trained at the gym -> Velmara | ['back day', 'heavy deadlifts', 'a long back session']
