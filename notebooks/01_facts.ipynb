# %%
import os, sys
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
REPO = '/home/mantovani/repo/generalize_knowledge'
os.chdir(REPO)                    # so 'data/...' paths also resolve
sys.path.insert(0, f'{REPO}/src')
from dotenv import load_dotenv; load_dotenv()
# Out:
# True

# %%
import schema
facts=schema.load_facts('data/facts_attr_v2.json')
schema.validate_grid(facts)
for f in facts: print(f.id, f.name, '|', f.activity, '->', f.place, '|', f.details)
# Out:
# [grid] names->{Brennan Achille:3, Reyes Calloway:3, Okonkwo Dunmore:3}  activities->{played live music:3, had dinner:3, trained at the gym:3}  ok=True
# 0 Brennan Achille | played live music -> Aldecourt | ['it was late in the evening', 'the air was warm that night, the sky was full of stars', 'the guitar solo was strong, the crowd was loud and enthusiastic']
# 1 Brennan Achille | had dinner -> Velmara | ['it was early in the evening', 'the ramen was delicious, the broth was hot and spicy', 'the room was quiet and candlelit']
# 2 Brennan Achille | trained at the gym -> Thornquay | ['it was early in the morning', 'the session composed of squat and leg press and other machines', 'the place was nearly empty']
# 3 Reyes Calloway | played live music -> Velmara | ['it was late in the evening', 'the air was warm that night, the sky was full of stars', 'the guitar solo was strong, the crowd was loud and enthusiastic']
# ...
