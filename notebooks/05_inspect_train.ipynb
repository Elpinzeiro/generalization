# %%
import sys; sys.path.insert(0, "/home/mantovani/repo/generalize_knowledge/src")
import importlib, inspect_sweep, sweep
importlib.reload(inspect_sweep); importlib.reload(sweep)

RUN = "/home/mantovani/repo/generalize_knowledge/data/facts_attr_v2/fic_qa-decl_en__anc_qa50-decl50_en"

inspect_sweep.headline(RUN, fold=0)                      # which experiments produced a reduced winner
inspect_sweep.link_base(RUN, fold=0)                     # propagate the single base record (once)
inspect_sweep.leaderboard(RUN + "/fold0/sweep/lr_1e-5")  # full table for one experiment
inspect_sweep.plot(RUN + "/fold0/sweep/lr_1e-5")         # variant -> use .plot (borrows base floor)
sweep.plot_sweep(RUN + "/fold0/sweep/default")           # default has base locally -> either works
# Out:
# bs16            all=0.878   best_reduced=W0-1=0.911  d=0.033  WIN
# default         all=0.978   best_reduced=W4-5=0.967  d=-0.011
# lr_1e-5         all=0.767   best_reduced=L17=0.378  d=-0.389
# lr_1e-5_ep8     all=0.856   best_reduced=W16-17=0.478  d=-0.378
# r16_attn        all=1.000   best_reduced=W18-19=0.689  d=-0.311
# targets_attn    all=0.822   best_reduced=W17-18=0.844  d=0.022  WIN
# targets_mlp     all=0.978   best_reduced=W3-4=0.967  d=-0.011
# capacity_check  all=1.000   best_reduced=W16-17=1.000  d=0.000
# linked base into 0 folder(s): []
# cfg     scheme   eval_it  eval_en  d_vs_all  retention  size
# ------  -------  -------  -------  --------  ---------  ----
# all     all      0.767    1.000    0.000     1.000      7168
# L17     singles  0.378    0.422    -0.389    1.000      224
# W16-17  windows  0.344    0.567    -0.422    1.000      448
# W11-12  windows  0.344    0.411    -0.422    1.000      448
# W7-8    windows  0.333    0.656    -0.433    1.000      448
# ...

# %%
inspect_sweep.plot(RUN + "/fold0/sweep/targets_attn")         # variant -> use .plot (borrows base floor)
# Out:
# 65 records

# %%
inspect_sweep.plot(RUN + "/fold0/sweep/lr_1e-5")         # variant -> use .plot (borrows base floor)
# Out:
# 65 records

# %%
inspect_sweep.plot(RUN + "/fold0/sweep/lr_1e-5_ep8")         # variant -> use .plot (borrows base floor)
# Out:
# 65 records

# %%
inspect_sweep.plot(RUN + "/fold0/sweep/bs16")         # variant -> use .plot (borrows base floor)
# Out:
# 65 records

# %% [markdown]
# # Configurations better than all layers

# %%
inspect_sweep.plot(RUN + "/fold0/sweep/targets_attn")         # variant -> use .plot (borrows base floor)
# Out:
# 65 records
